# %%
import boto3

# Let's use Amazon S3
s3 = boto3.resource('s3')

# %%
BUCKET_NAME = 'ann-arbor-'

# %%
# Print out bucket names
for bucket in s3.buckets.all():
    print(bucket.name)
# Out:
# ---------------------------------------------------------------------------
# NoCredentialsError                        Traceback (most recent call last)
# /var/folders/57/p4z_h0711cx5h0by91hbgqdc0000gp/T/ipykernel_86318/3322455051.py in <module>
#       1 # Print out bucket names
# ----> 2 for bucket in s3.buckets.all():
#       3     print(bucket.name)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/boto3/resources/collection.py in __iter__(self)
#      81
#      82         count = 0
# ---> 83         for page in self.pages():
#      84             for item in page:
#      85                 yield item
#
# ~/opt/anaconda3/lib/python3.9/site-packages/boto3/resources/collection.py in pages(self)
#     159                          self._parent.meta.service_name,
#     160                          self._py_operation_name, params)
# --> 161             pages = [getattr(client, self._py_operation_name)(**params)]
#     162
# ...
